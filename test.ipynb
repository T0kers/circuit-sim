# %%
import numpy as np

# %%
a = np.array([
    [1, 2, 3],
    [4, 5, 6]
])

# %%
np.delete(a, np.array([False, True, False]), axis=1)
# Out:
# array([[1, 3],
#        [4, 6]])

# %%
np.delete(a, np.array([False, True]), axis=0)
# Out:
# array([[1, 2, 3]])
